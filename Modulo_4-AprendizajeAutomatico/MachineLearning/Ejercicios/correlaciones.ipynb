# %% [markdown]
# # Correlaciones

# %%
# Load Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset

# %% [markdown]
# Leamos el dataset a utilizar.

# %%
# Load the dataset 
dat = pd.read_csv("../datasets/iris.csv", sep='|', decimal=',')
dat
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Visualización

# %% [markdown]
# Algunas correlaciones pueden observarse mediante visualizaciones de una variable con respecto a la otra. Por ejemplo, podemos realizar un scatter plot que muestre *Sepal_Width* con respecto a *Sepal_Length*.

# %%
plt.scatter(x = dat.Sepal_Length, y = dat.Petal_Length)
plt.show()

# %% [markdown]
# La correlación parece evidente a simple vista.

# %% [markdown]
# Podemos hacer esto mismo para todas las variables numéricas del dataset.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dat, figsize = (10,10))
# Out:
# array([[<AxesSubplot:xlabel='Sepal_Length', ylabel='Sepal_Length'>,
#         <AxesSubplot:xlabel='Sepal_Width', ylabel='Sepal_Length'>,
#         <AxesSubplot:xlabel='Petal_Length', ylabel='Sepal_Length'>,
#         <AxesSubplot:xlabel='Petal_Width', ylabel='Sepal_Length'>],
#        [<AxesSubplot:xlabel='Sepal_Length', ylabel='Sepal_Width'>,
#         <AxesSubplot:xlabel='Sepal_Width', ylabel='Sepal_Width'>,
#         <AxesSubplot:xlabel='Petal_Length', ylabel='Sepal_Width'>,
#         <AxesSubplot:xlabel='Petal_Width', ylabel='Sepal_Width'>],
#        [<AxesSubplot:xlabel='Sepal_Length', ylabel='Petal_Length'>,
#         <AxesSubplot:xlabel='Sepal_Width', ylabel='Petal_Length'>,
#         <AxesSubplot:xlabel='Petal_Length', ylabel='Petal_Length'>,
#         <AxesSubplot:xlabel='Petal_Width', ylabel='Petal_Length'>],
#        [<AxesSubplot:xlabel='Sepal_Length', ylabel='Petal_Width'>,
#         <AxesSubplot:xlabel='Sepal_Width', ylabel='Petal_Width'>,
#         <AxesSubplot:xlabel='Petal_Length', ylabel='Petal_Width'>,
#         <AxesSubplot:xlabel='Petal_Width', ylabel='Petal_Width'>]],
#       dtype=object)

# %% [markdown]
# ## Cálculo numérico

# %% [markdown]
# Podemos calcular el valor numérico de esta correlación con la fórmula vista en clase.

# %%
np.corrcoef(dat.Sepal_Length, dat.Petal_Length)[0, 1]
# Out:
# 0.8717537758865832

# %% [markdown]
# ## Matriz de correlaciones

# %% [markdown]
# Podemos crear la matriz de correlaciones entre todas las variables numéricas del dataset.

# %%
corr = dat.corr()
corr
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.117570      0.871754     0.817941
# Sepal_Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal_Length      0.871754    -0.428440      1.000000     0.962865
# Petal_Width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Esta matriz puede ser formateada para ser más informativa.

# %%
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-24-ce9744728a5b>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_49268_row0_col0, #T_49268_row1_col1, #T_49268_row2_col2, #T_49268_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_49268_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_49268_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_49268_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_49268_row1_col0, #T_49268_row1_col2, #T_49268_row1_col3, #T_49268_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_49268_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_49268_row2_col3, #T_49268_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_49268_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_49268_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_49268_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Sepal_Length</th>
#       <th class="col_heading level0 col1" >Sepal_Width</th>
#       <th class="col_heading level0 col2" >Petal_Length</th>
#       <th class="col_heading level0 col3" >Petal_Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49268_level0_row0" class="row_heading level0 row0" >Sepal_Length</th>
#       <td id="T_49268_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_49268_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_49268_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_49268_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_49268_level0_row1" class="row_heading level0 row1" >Sepal_Width</th>
#       <td id="T_49268_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_49268_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_49268_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_49268_row1_col3" class="data row1 col3" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_49268_level0_row2" class="row_heading level0 row2" >Petal_Length</th>
#       <td id="T_49268_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_49268_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_49268_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_49268_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_49268_level0_row3" class="row_heading level0 row3" >Petal_Width</th>
#       <td id="T_49268_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_49268_row3_col1" class="data row3 col1" >-0.37</td>
#       <td id="T_49268_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_49268_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# También podemos mostrarla sin números.

# %%
corr.style.background_gradient(cmap='coolwarm').set_properties(**{'font-size': '0pt'})
# Out:
# <style type="text/css">
# #T_e2ceb_row0_col0, #T_e2ceb_row1_col1, #T_e2ceb_row2_col2, #T_e2ceb_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row1_col0, #T_e2ceb_row1_col2, #T_e2ceb_row1_col3, #T_e2ceb_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row2_col3, #T_e2ceb_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_e2ceb_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# </style>
# <table id="T_e2ceb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Sepal_Length</th>
#       <th class="col_heading level0 col1" >Sepal_Width</th>
#       <th class="col_heading level0 col2" >Petal_Length</th>
#       <th class="col_heading level0 col3" >Petal_Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ceb_level0_row0" class="row_heading level0 row0" >Sepal_Length</th>
#       <td id="T_e2ceb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e2ceb_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_e2ceb_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_e2ceb_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_e2ceb_level0_row1" class="row_heading level0 row1" >Sepal_Width</th>
#       <td id="T_e2ceb_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_e2ceb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e2ceb_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_e2ceb_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_e2ceb_level0_row2" class="row_heading level0 row2" >Petal_Length</th>
#       <td id="T_e2ceb_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_e2ceb_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_e2ceb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e2ceb_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_e2ceb_level0_row3" class="row_heading level0 row3" >Petal_Width</th>
#       <td id="T_e2ceb_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_e2ceb_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_e2ceb_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_e2ceb_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.matshow(corr, cmap='coolwarm')
cb = plt.colorbar()
plt.xticks(range(dat.select_dtypes(['number']).shape[1]), dat.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(dat.select_dtypes(['number']).shape[1]), dat.select_dtypes(['number']).columns, fontsize=14)
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
plt.show()
