# %%
# !git clone https://github.com/hiteshmishra708/python-chatbot.git
# Out:
# Cloning into 'python-chatbot'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 20 (delta 3), reused 17 (delta 3), pack-reused 0
# Unpacking objects: 100% (20/20), 478.89 KiB | 4.99 MiB/s, done.

# %%
# %cd python-chatbot
# Out:
# /content/python-chatbot

# %%
# !ls
# Out:
# chatbot_model.h5  classes.pkl	README.md	  train_bot.py
# chatgui.py	  intents.json	requirements.txt  words.pkl

# %%
# !cat intents.json
# Out:
# {
#     "intents": [
#         {
#             "tag": "greeting",
#             "patterns": [
#                 "Hi there",
#                 "How are you",
#                 "Is anyone there?",
#                 "Hey",
#                 "Hola",
#                 "Hello",
#                 "Good day"
#             ],
#             "responses": [
#                 "Hi there, how can I help?"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "goodbye",
#             "patterns": [
#                 "Bye",
#                 "See you later",
#                 "Goodbye",
#                 "Nice chatting to you, bye",
#                 "Till next time"
#             ],
#             "responses": [
#                 "Bye! Have a nice day"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "thanks",
#             "patterns": [
#                 "Thanks",
#                 "Thank you",
#                 "That's helpful",
#                 "Awesome, thanks",
#                 "Thanks for helping me"
#             ],
#             "responses": [
#                 "Happy to help!"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "noanswer",
#             "patterns": [],
#             "responses": [
#                 "Sorry, can't understand you"
#             ],
#             "context": [
#                 ""
#             ]
#         }
#     ]
# }

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

import json
import pickle

import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()
words = []
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)
print(intents)

# intents: opciones de conversación (lo que el chatbot contestará al usuario)
# patterns: interacciones del usuario (lo que pensamos que puede contestar)
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # tokenizamos
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # añadimos las palabras
        documents.append((w, intent['tag']))

        # añadimos las clases a nuestra lista
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]

pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))

# preparamos los datos para entrenar la red
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # bag of words
    bag = []
    # lista de tokens
    pattern_words = doc[0]
    # lemmatizacion de los tokens
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

training = np.array(training)
# creamos los conjuntos de entrenamiento y test: X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])

# creación del modelo
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, weight_decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# entrenamos y guardamos el modelo
hist = model.fit(np.array(train_x), np.array(train_y), epochs=300, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# {'intents': [{'tag': 'greeting', 'patterns': ['Hi there', 'How are you', 'Is anyone there?', 'Hey', 'Hola', 'Hello', 'Good day'], 'responses': ['Hi there, how can I help?'], 'context': ['']}, {'tag': 'goodbye', 'patterns': ['Bye', 'See you later', 'Goodbye', 'Nice chatting to you, bye', 'Till next time'], 'responses': ['Bye! Have a nice day'], 'context': ['']}, {'tag': 'thanks', 'patterns': ['Thanks', 'Thank you', "That's helpful", 'Awesome, thanks', 'Thanks for helping me'], 'responses': ['Happy to help!'], 'context': ['']}, {'tag': 'noanswer', 'patterns': [], 'responses': ["Sorry, can't understand you"], 'context': ['']}]}
# <ipython-input-7-cf767e50b958>:62: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/300
# 4/4 [==============================] - 1s 11ms/step - loss: 1.1415 - accuracy: 0.2353
# Epoch 2/300
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1638 - accuracy: 0.2941
# Epoch 3/300
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1448 - accuracy: 0.2353
# Epoch 4/300
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1249 - accuracy: 0.2941
# Epoch 5/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9948 - accuracy: 0.5882
# Epoch 6/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0996 - accuracy: 0.4118
# Epoch 7/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9300 - accuracy: 0.4706
# Epoch 8/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8067 - accuracy: 0.7647
# Epoch 9/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7927 - accuracy: 0.7059
# Epoch 10/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8690 - accuracy: 0.5294
# Epoch 11/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8746 - accuracy: 0.5294
# Epoch 12/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7421 - accuracy: 0.8235
# Epoch 13/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6741 - accuracy: 0.8235
# Epoch 14/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6714 - accuracy: 0.7647
# Epoch 15/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6251 - accuracy: 0.8235
# Epoch 16/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5486 - accuracy: 0.8824
# Epoch 17/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5580 - accuracy: 0.8824
# Epoch 18/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4211 - accuracy: 0.8824
# Epoch 19/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3787 - accuracy: 0.8824
# Epoch 20/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3859 - accuracy: 0.8824
# Epoch 21/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5752 - accuracy: 0.8235
# Epoch 22/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5396 - accuracy: 0.8824
# Epoch 23/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3261 - accuracy: 0.8824
# Epoch 24/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.8824
# Epoch 25/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3785 - accuracy: 1.0000
# Epoch 26/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2885 - accuracy: 1.0000
# Epoch 27/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 1.0000
# Epoch 28/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2108 - accuracy: 0.9412
# Epoch 29/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1773 - accuracy: 0.9412
# Epoch 30/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2836 - accuracy: 0.9412
# Epoch 31/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1123 - accuracy: 1.0000
# Epoch 32/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2409 - accuracy: 0.9412
# Epoch 33/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1148 - accuracy: 0.9412
# Epoch 34/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1732 - accuracy: 1.0000
# Epoch 35/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1004 - accuracy: 1.0000
# Epoch 36/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1141 - accuracy: 0.9412
# Epoch 37/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1007 - accuracy: 1.0000
# Epoch 38/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1086 - accuracy: 1.0000
# Epoch 39/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1893 - accuracy: 0.9412
# Epoch 40/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1016 - accuracy: 1.0000
# Epoch 41/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 1.0000
# Epoch 42/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1090 - accuracy: 1.0000
# Epoch 43/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 44/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1246 - accuracy: 0.9412
# Epoch 45/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 46/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 47/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 48/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 49/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 50/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0840 - accuracy: 0.9412
# Epoch 51/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1506 - accuracy: 1.0000
# Epoch 52/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 53/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 54/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 55/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 56/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 57/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 58/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0655 - accuracy: 1.0000
# Epoch 59/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0829 - accuracy: 1.0000
# Epoch 60/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 61/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1161 - accuracy: 0.9412
# Epoch 62/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1654 - accuracy: 0.9412
# Epoch 63/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 64/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 65/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 66/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 67/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 68/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 69/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 70/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 71/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 72/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 73/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 74/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9412
# Epoch 75/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 76/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 77/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 78/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0664 - accuracy: 1.0000
# Epoch 79/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 80/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 81/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 82/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 83/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 84/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 85/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 86/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 87/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 88/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0619 - accuracy: 0.9412
# Epoch 89/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 90/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 91/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 92/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 93/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 94/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 95/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 96/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 97/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 98/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 99/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 100/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 101/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 102/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 103/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 104/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 105/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0495 - accuracy: 0.9412
# Epoch 106/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 107/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 108/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 109/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 110/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 111/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9412
# Epoch 112/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 113/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 114/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 115/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 116/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 117/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 118/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0779 - accuracy: 0.9412
# Epoch 119/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 120/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 121/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 122/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 123/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 124/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 125/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 126/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 127/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 128/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 129/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 130/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 131/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 132/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 133/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 134/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 135/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 136/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 137/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 138/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 139/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 140/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 141/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 142/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 143/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 144/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 145/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 146/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 147/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 148/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 149/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 150/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 151/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 152/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 153/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 154/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 155/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 156/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 157/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 158/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 159/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 160/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 161/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 162/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 163/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 164/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 165/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 166/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 167/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 168/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 169/300
# 4/4 [==============================] - 0s 7ms/step - loss: 7.3972e-04 - accuracy: 1.0000
# Epoch 170/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 171/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 172/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 173/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 174/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 175/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 176/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 177/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 178/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 179/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 180/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 181/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 182/300
# 4/4 [==============================] - 0s 6ms/step - loss: 7.8868e-04 - accuracy: 1.0000
# Epoch 183/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9412
# Epoch 184/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 185/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 186/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 187/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 188/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 189/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 190/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 191/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 192/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 193/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 194/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 195/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 196/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 197/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 198/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 199/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 200/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 201/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 202/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 203/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 204/300
# 4/4 [==============================] - 0s 5ms/step - loss: 6.6613e-04 - accuracy: 1.0000
# Epoch 205/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 206/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 207/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 208/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 209/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 210/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 211/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 212/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 213/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 214/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 215/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9412
# Epoch 216/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 217/300
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3130e-04 - accuracy: 1.0000
# Epoch 218/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 219/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 220/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 221/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 222/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 223/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 224/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 225/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 226/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 227/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 228/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 229/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 230/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 231/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 232/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 233/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 234/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 235/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 236/300
# 4/4 [==============================] - 0s 5ms/step - loss: 9.8761e-04 - accuracy: 1.0000
# Epoch 237/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 238/300
# 4/4 [==============================] - 0s 5ms/step - loss: 3.6559e-04 - accuracy: 1.0000
# Epoch 239/300
# 4/4 [==============================] - 0s 5ms/step - loss: 8.3366e-05 - accuracy: 1.0000
# Epoch 240/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 241/300
# 4/4 [==============================] - 0s 5ms/step - loss: 7.8852e-04 - accuracy: 1.0000
# Epoch 242/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 243/300
# 4/4 [==============================] - 0s 6ms/step - loss: 9.0779e-04 - accuracy: 1.0000
# Epoch 244/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 245/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 246/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 247/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 248/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 249/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 250/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 251/300
# 4/4 [==============================] - 0s 6ms/step - loss: 1.8309e-04 - accuracy: 1.0000
# Epoch 252/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 253/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 254/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 255/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 256/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 257/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 258/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 259/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 260/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 261/300
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6569e-04 - accuracy: 1.0000
# Epoch 262/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 263/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 264/300
# 4/4 [==============================] - 0s 5ms/step - loss: 5.1524e-04 - accuracy: 1.0000
# Epoch 265/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 266/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 267/300
# 4/4 [==============================] - 0s 5ms/step - loss: 6.8663e-04 - accuracy: 1.0000
# Epoch 268/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 269/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 270/300
# 4/4 [==============================] - 0s 5ms/step - loss: 5.4155e-04 - accuracy: 1.0000
# Epoch 271/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 272/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 273/300
# 4/4 [==============================] - 0s 6ms/step - loss: 9.9149e-05 - accuracy: 1.0000
# Epoch 274/300
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1708e-04 - accuracy: 1.0000
# Epoch 275/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 276/300
# 4/4 [==============================] - 0s 5ms/step - loss: 3.9455e-04 - accuracy: 1.0000
# Epoch 277/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 278/300
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0473e-04 - accuracy: 1.0000
# Epoch 279/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 280/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 281/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 282/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 283/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 284/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 285/300
# 4/4 [==============================] - 0s 7ms/step - loss: 7.0098e-04 - accuracy: 1.0000
# Epoch 286/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 287/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 288/300
# 4/4 [==============================] - 0s 5ms/step - loss: 6.0666e-04 - accuracy: 1.0000
# Epoch 289/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 290/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 291/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 292/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 293/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 294/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 295/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 296/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 297/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 298/300
# 4/4 [==============================] - 0s 6ms/step - loss: 4.2530e-04 - accuracy: 1.0000
# Epoch 299/300
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6741e-04 - accuracy: 1.0000
# Epoch 300/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# model created

# %%
import nltk, json, random, pickle
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# preprocesamos la entrada
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# creación del BoW
def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def calcula_pred(sentence, model):
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def respuesta(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def responde(msg):
    ints = calcula_pred(msg, model)
    res = respuesta(ints, intents)
    return res

entrada = ''
print('Welcome! Type "exit" to quit.')

while entrada != 'exit':
    entrada = str(input(""))
    res = responde(entrada)
    print('AI:' + res)
# Out:
# Bienvenido! Para salir, escriba "exit"
# hello
# 1/1 [==============================] - 0s 116ms/step
# AI:Hi there, how can I help?
# I need help
# 1/1 [==============================] - 0s 24ms/step
# AI:Hi there, how can I help?
# what can you do for me?
# 1/1 [==============================] - 0s 23ms/step
# AI:Happy to help!
# exit
# 1/1 [==============================] - 0s 23ms/step
# AI:Hi there, how can I help?

# %% [markdown]
# ### Recursos:
# - https://planetachatbot.com/tutorial-chatbot-usando-nltk-keras/
# - https://github.com/hiteshmishra708/python-chatbot/
# - https://www.pycodemates.com/2021/11/build-a-AI-chatbot-using-python-and-deep-learning.html
